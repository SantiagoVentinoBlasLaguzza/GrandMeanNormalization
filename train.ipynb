# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Final Training Script for Beta-VAE + Classifier (AD vs CN)
Using best hyperparameters found during sweep.

Author: Renzo (adapted from sweep script) - 2025-05-03
Requires:  ▸ pip install torch numpy scikit-learn lightgbm
"""
import os
import random
import time
import warnings
import math
import argparse
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split # Optional: for classifier tuning
import lightgbm as lgb
import joblib # For saving sklearn models

# ────────────────────────── Best Hyperparameters & Config ──────────────────────
BEST_HP = {
    'lr': 2.169848131729575e-05,
    'batch_size': 128,
    'beta': 50,
    'beta_ramp_epochs': 200,
    'latent_dim': 512,
    'k_filters': 48,
    'epochs': 4000 # User specified final training epochs
}

PROJECT_DIR = '/content/drive/MyDrive/GrandMeanNorm' # Make sure this path is correct
FOLD = 1
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Early stopping settings for final training
# Increase patience significantly or disable by setting patience >= epochs
EARLY_STOP_PATIENCE = 100
# Output directory for saved models
OUTPUT_DIR = os.path.join(PROJECT_DIR, f'final_model_fold_{FOLD}')
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ──────────────────────────── Data Utilities ───────────────────────────────────
def load_fold(fold=1):
    """Loads preprocessed data for a specific fold."""
    fdir = os.path.join(PROJECT_DIR, f'fold_{fold}')
    try:
        load = lambda n: torch.load(os.path.join(fdir, n), map_location='cpu', weights_only=False)
        trX, vaX, teX = load('train_z.pt'), load('val_z.pt'), load('test_z.pt')
        trY_str, vaY_str, teY_str = load('train_labels.pt'), load('val_labels.pt'), load('test_labels.pt')
    except FileNotFoundError as e:
        print(f"Error loading data for fold {fold}: {e}")
        print(f"Please ensure the files train_z.pt, val_z.pt, test_z.pt, train_labels.pt, etc., exist in {fdir}")
        raise
    except Exception as e:
        print(f"An unexpected error occurred during data loading: {e}")
        raise

    # Binarize labels (AD=1, CN=0)
    def binarize(Y_str):
        # Ensure Y_str is a list or similar iterable of strings
        if not isinstance(Y_str, (list, tuple)):
             print(f"Warning: Labels are not in expected list/tuple format. Type: {type(Y_str)}. Attempting conversion.")
             # Add specific handling if needed, e.g., if it's a tensor or numpy array
             if hasattr(Y_str, 'tolist'): Y_str = Y_str.tolist()
             else: Y_str = list(Y_str) # Basic attempt

        return torch.tensor([1 if isinstance(s, str) and 'AD_' in s else 0 for s in Y_str], dtype=torch.long)

    trY, vaY, teY = binarize(trY_str), binarize(vaY_str), binarize(teY_str)

    print(f"Data loaded for Fold {fold}:")
    print(f"  Train X: {trX.shape}, Train Y: {trY.shape}")
    print(f"  Val   X: {vaX.shape}, Val   Y: {vaY.shape}")
    print(f"  Test  X: {teX.shape}, Test  Y: {teY.shape}")
    print(f"  Class distribution in Train Y: {torch.bincount(trY)}")
    print(f"  Class distribution in Val Y:   {torch.bincount(vaY)}")
    print(f"  Class distribution in Test Y:  {torch.bincount(teY)}")


    return trX, vaX, teX, trY, vaY, teY

# ─────────────────────────────── Beta-VAE Model ────────────────────────────────
# Identical to the sweep script
class Encoder(nn.Module):
    def __init__(self, c_in, latent, k=32):
        super().__init__()
        # Calculate expected flattened size dynamically if possible, otherwise use known value
        # Example dynamic calculation (assumes input H, W are known and consistent)
        # self.final_h = ... # Calculate based on conv layers
        # self.final_w = ...
        # linear_input_size = 4 * k * self.final_h * self.final_w
        #linear_input_size = 4 * k * 19 * 19 # Hardcoded based on original script - check if input size is always 160x160x1 -> 19x19 after convs
        #print(f"Encoder: Linear input size calculated as {linear_input_size}")

        self.conv = nn.Sequential(
            nn.Conv2d(c_in, k, kernel_size=4, stride=2, padding=1), # Adjusted padding for potentially different output size
            nn.ReLU(),
            nn.Conv2d(k, 2 * k, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(2 * k, 4 * k, kernel_size=3, stride=2, padding=1), # Adjusted padding
            nn.ReLU()
            # Add AdaptiveAvgPool2d if feature map size varies
            # nn.AdaptiveAvgPool2d((expected_h, expected_w))
        )
        # Dummy input to infer shape after convolutions
        with torch.no_grad():
            dummy = torch.zeros(1, c_in, 166, 166)  # Shape of your real input
            out = self.conv(dummy)
            flat_dim = out.view(1, -1).shape[1]
            print(f"[DEBUG] Flattened dim after convs: {flat_dim}")

        self.flat = nn.Flatten()
        self.mu = nn.Linear(flat_dim, latent)
        self.logvar = nn.Linear(flat_dim, latent)
        self.flat_dim = flat_dim
        self.reshape_dims = out.shape[1:]  # (C, H, W)

    def forward(self, x):
        h = self.conv(x)
        # print("Encoder conv output shape:", h.shape) # Debug print
        h_flat = self.flat(h)
        # print("Encoder flattened shape:", h_flat.shape) # Debug print
        return self.mu(h_flat), self.logvar(h_flat)


class Decoder(nn.Module):
    def __init__(self, latent, c_out, k=32, flat_dim=69312, reshape_dims=(192, 19, 19)):
        super().__init__()
        self.reshape_dims = reshape_dims
        self.fc = nn.Sequential(
            nn.Linear(latent, flat_dim),
            nn.ReLU()
        )
        self.deconv = nn.Sequential(
            nn.ConvTranspose2d(reshape_dims[0], 2 * k, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(2 * k, k, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(k, c_out, kernel_size=4, stride=2, padding=1),
        )


    def forward(self, z):
        h = self.fc(z)
        # print("Decoder fc output shape:", h.shape) # Debug print
        h_reshaped = h.view(-1, *self.reshape_dims)
        # print("Decoder reshaped shape:", h_reshaped.shape) # Debug print
        recon = self.deconv(h_reshaped)
        # print("Decoder deconv output shape:", recon.shape) # Debug print
        return recon


class BetaVAE(nn.Module):
    def __init__(self, c_in, latent, k=32):
        super().__init__()
        self.enc = Encoder(c_in, latent, k)
        self.dec = Decoder(latent, c_in, k, self.enc.flat_dim, self.enc.reshape_dims)


        #self.dec = Decoder(latent, c_in, k)

    def reparam(self, mu, logv):
        std = torch.exp(0.5 * logv)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu, logv = self.enc(x)
        z = self.reparam(mu, logv)
        return self.dec(z), mu, logv

def loss_vae(x_hat, x, mu, logv, beta, current_epoch, beta_ramp_epochs):
    """Calculates Beta-VAE loss with beta ramp-up."""
    # Ensure x_hat and x have the same shape
    if x_hat.shape != x.shape:
         # Attempt to resize x_hat to match x using interpolation
         x_hat = F.interpolate(x_hat, size=x.shape[2:], mode='bilinear', align_corners=False)
         # Or pad/crop if size difference is small and consistent
         # Or raise an error if the mismatch indicates a deeper problem
         # raise ValueError(f"Shape mismatch: x_hat {x_hat.shape}, x {x.shape}")

    # Reconstruction Loss (MSE per pixel, summed over pixels, averaged over batch)
    recon = F.mse_loss(x_hat, x, reduction='sum') / x.size(0)
    # KLD Loss (averaged over batch)
    kld = -0.5 * torch.sum(1 + logv - mu.pow(2) - logv.exp(), dim=1) # Sum over latent dims
    kld = torch.mean(kld) # Average over batch dimension

    # Beta Ramp-up
    beta_effective = min(beta, beta * (current_epoch / beta_ramp_epochs))

    total_loss = recon + beta_effective * kld
    return total_loss, recon, kld, beta_effective


# ────────────────────────── Latent Space Encoding ─────────────────────────────
def encode_latents(encoder, tensor, use_sigma, bs=128, device=DEVICE):
    """Encodes data into latent representations using the trained encoder."""
    encoder.eval() # Set encoder to evaluation mode
    dataset = TensorDataset(tensor)
    loader = DataLoader(dataset, batch_size=bs, shuffle=False, pin_memory=True)
    Z_list = []
    with torch.no_grad():
        for (x,) in loader:
            x = x.to(device)
            mu, logv = encoder(x)
            if use_sigma:
                sigma = torch.exp(0.5 * logv)
                z = torch.cat([mu, sigma], dim=1)
            else:
                z = mu
            Z_list.append(z.cpu().numpy())
    return np.vstack(Z_list)

# ────────────────────────── Classifier Evaluation ─────────────────────────────
def evaluate_classifiers(encoder, trX, trY, teX, teY, device=DEVICE, seed=SEED):
    """Trains and evaluates multiple classifiers on latent features."""
    print("\n--- Evaluating Classifiers on Latent Features ---")

    results = {}

    for use_sigma, suffix in [(False, "_mu"), (True, "_mu_sigma")]:
        print(f"\nEncoding latent features (use_sigma={use_sigma})...")
        Z_train = encode_latents(encoder, trX, use_sigma, device=device)
        Z_test = encode_latents(encoder, teX, use_sigma, device=device)
        y_train = trY.numpy()
        y_test = teY.numpy()

        print(f"Train features shape: {Z_train.shape}, Test features shape: {Z_test.shape}")
        print(f"Feature type: {'Mu + Sigma' if use_sigma else 'Mu only'}")

        classifiers = {
            "Logistic Regression": LogisticRegression(max_iter=5000, class_weight='balanced', random_state=seed, C=1.0, solver='liblinear'), # Increased max_iter, specify solver
            "SVM (RBF Kernel)": SVC(probability=True, class_weight='balanced', kernel='rbf', random_state=seed, C=1.0, gamma='scale'),
            "SVM (Linear Kernel)": SVC(probability=True, class_weight='balanced', kernel='linear', random_state=seed, C=1.0),
            "Random Forest": RandomForestClassifier(class_weight='balanced', n_estimators=200, random_state=seed, n_jobs=-1, max_depth=10, min_samples_leaf=5), # Added some regularization
            "LightGBM": lgb.LGBMClassifier(class_weight='balanced', random_state=seed, n_estimators=200, learning_rate=0.05, num_leaves=31) # Added common params
        }

        results[suffix] = {}

        for name, clf in classifiers.items():
            print(f"\nTraining {name}...")
            start_time = time.time()
            clf.fit(Z_train, y_train)
            train_time = time.time() - start_time
            print(f"Training finished in {train_time:.2f} seconds.")

            print(f"Evaluating {name}...")
            y_pred_proba = clf.predict_proba(Z_test)[:, 1]
            y_pred = clf.predict(Z_test) # Get class predictions

            acc = accuracy_score(y_test, y_pred)
            try:
                auc = roc_auc_score(y_test, y_pred_proba)
            except ValueError as e:
                 print(f"Warning: Could not calculate AUC for {name}. Error: {e}. Setting AUC to 0.0")
                 auc = 0.0 # Handle cases where AUC is undefined (e.g., only one class in y_test or y_pred_proba)


            print(f"Results for {name}{suffix}:")
            print(f"  Accuracy: {acc:.4f}")
            print(f"  AUC:      {auc:.4f}")
            print("\nConfusion Matrix:")
            print(confusion_matrix(y_test, y_pred))
            print("\nClassification Report:")
            print(classification_report(y_test, y_pred, target_names=['CN', 'AD']))


            results[suffix][name] = {'ACC': acc, 'AUC': auc, 'model': clf} # Store trained model too

            # Save the trained classifier
            clf_filename = os.path.join(OUTPUT_DIR, f"{name.replace(' ', '_').replace('(', '').replace(')', '')}{suffix}.joblib")
            try:
                joblib.dump(clf, clf_filename)
                print(f"Saved trained {name}{suffix} classifier to {clf_filename}")
            except Exception as e:
                 print(f"Error saving classifier {name}{suffix}: {e}")


    print("\n--- Classifier Evaluation Summary ---")
    for suffix, classifiers_results in results.items():
        print(f"\nFeature Type: {'Mu + Sigma' if suffix == '_mu_sigma' else 'Mu only'}")
        for name, metrics in classifiers_results.items():
            print(f"  {name}: Accuracy={metrics['ACC']:.4f}, AUC={metrics['AUC']:.4f}")

    return results


# ────────────────────────── VAE Training Function ─────────────────────────────
def train_vae(hp):
    """Trains the Beta-VAE model."""
    print("--- Starting VAE Training ---")
    print(f"Using device: {DEVICE}")
    print("Hyperparameters:")
    for key, val in hp.items():
        print(f"  {key}: {val}")

    # 1. Load Data
    trX, vaX, teX, trY, vaY, teY = load_fold(FOLD)
    C, H, W = trX.shape[1:] # Get channels, height, width from data
    print(f"Input data shape C,H,W: ({C}, {H}, {W})")


    # 2. Initialize Model, Optimizer
    vae = BetaVAE(C, hp['latent_dim'], hp['k_filters']).to(DEVICE)
    optimizer = optim.AdamW(vae.parameters(), lr=hp['lr'])
    scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE.type == 'cuda')) # Enable AMP only for CUDA

    # 3. Create DataLoader (Train on Train+Val as in original sweep script)
    # Consider training only on trX if you want vaX purely for validation/early stopping
    allX = torch.cat([trX, vaX])
    allY = torch.cat([trY, vaY]) # Combine labels if needed for other tasks later
    train_dataset = TensorDataset(allX) # VAE is unsupervised
    train_loader = DataLoader(train_dataset, batch_size=hp['batch_size'], shuffle=True,
                              pin_memory=True, num_workers=os.cpu_count() // 2 if os.cpu_count() > 1 else 1) # Use available cores

    # Separate validation loader for early stopping based on reconstruction
    val_dataset = TensorDataset(vaX)
    val_loader = DataLoader(val_dataset, batch_size=hp['batch_size'], shuffle=False)


    print(f"Training VAE for {hp['epochs']} epochs...")
    best_val_loss = math.inf
    epochs_no_improve = 0
    best_state_dict = None # Store the best model state

    start_train_time = time.time()

    # 4. Training Loop
    for epoch in range(1, hp['epochs'] + 1):
        epoch_start_time = time.time()
        vae.train()
        total_loss, total_recon, total_kld = 0, 0, 0

        for (x_batch,) in train_loader:
            x_batch = x_batch.to(DEVICE)
            optimizer.zero_grad()

            with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                x_hat, mu, logv = vae(x_batch)
                loss, recon, kld, beta_eff = loss_vae(x_hat, x_batch, mu, logv,
                                                      hp['beta'], epoch, hp['beta_ramp_epochs'])

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()
            total_recon += recon.item()
            total_kld += kld.item()

        avg_loss = total_loss / len(train_loader)
        avg_recon = total_recon / len(train_loader)
        avg_kld = total_kld / len(train_loader)

        # 5. Validation Step (for Early Stopping)
        vae.eval()
        val_loss, val_recon, val_kld = 0, 0, 0
        with torch.no_grad():
            for (x_val_batch,) in val_loader:
                 x_val_batch = x_val_batch.to(DEVICE)
                 with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                     x_val_hat, mu_val, logv_val = vae(x_val_batch)
                     v_loss, v_recon, v_kld, _ = loss_vae(x_val_hat, x_val_batch, mu_val, logv_val,
                                                          hp['beta'], epoch, hp['beta_ramp_epochs']) # Use fixed beta for validation comparison
                 val_loss += v_loss.item()
                 val_recon += v_recon.item()
                 val_kld += v_kld.item()


        avg_val_loss = val_loss / len(val_loader)
        avg_val_recon = val_recon / len(val_loader)
        avg_val_kld = val_kld / len(val_loader)

        epoch_time = time.time() - epoch_start_time

        print(f"Epoch {epoch}/{hp['epochs']} [{epoch_time:.2f}s] - "
              f"Train Loss: {avg_loss:.2f} (Recon: {avg_recon:.2f}, KLD: {avg_kld:.2f}, Beta: {beta_eff:.2f}) | "
              f"Val Loss: {avg_val_loss:.2f} (Recon: {avg_val_recon:.2f}, KLD: {avg_val_kld:.2f})")

        # 6. Early Stopping Check & Save Best Model
        if avg_val_loss < best_val_loss - 1e-4: # Added tolerance
            best_val_loss = avg_val_loss
            epochs_no_improve = 0
            # Save the state dict of the best model found so far
            best_state_dict = {k: v.clone().cpu() for k, v in vae.state_dict().items()} # Save to CPU
            print(f"  ** New best validation loss: {best_val_loss:.4f}. Saving model state. **")
        else:
            epochs_no_improve += 1
            print(f"  Validation loss did not improve for {epochs_no_improve} epoch(s).")

        if epochs_no_improve >= EARLY_STOP_PATIENCE:
            print(f"\nEarly stopping triggered after {epoch} epochs due to no improvement in validation loss for {EARLY_STOP_PATIENCE} epochs.")
            break

    total_train_time = time.time() - start_train_time
    print(f"\n--- VAE Training Finished ---")
    print(f"Total training time: {total_train_time:.2f} seconds")

    # 7. Load Best Model State
    if best_state_dict:
        print(f"Loading best model state found at epoch {epoch - epochs_no_improve} with validation loss: {best_val_loss:.4f}")
        vae.load_state_dict(best_state_dict)
        vae = vae.to(DEVICE) # Ensure model is on the correct device after loading
    else:
        print("Warning: No best model state was saved (perhaps training stopped early or validation loss never improved). Using the final model state.")


    # 8. Save the trained VAE Encoder
    encoder_save_path = os.path.join(OUTPUT_DIR, 'vae_encoder_final.pt')
    try:
        torch.save(vae.enc.state_dict(), encoder_save_path)
        print(f"Saved trained VAE encoder state dictionary to {encoder_save_path}")
    except Exception as e:
        print(f"Error saving VAE encoder: {e}")


    # 9. Return necessary components for classification
    return vae.enc, trX, trY, teX, teY


# ────────────────────────────── Main Execution ────────────────────────────────
if __name__ == "__main__":
    warnings.filterwarnings('ignore', category=FutureWarning) # Suppress some sklearn/numpy warnings
    warnings.filterwarnings('ignore', category=UserWarning) # Suppress other common warnings

    # Train the VAE
    final_encoder, train_X, train_Y, test_X, test_Y = train_vae(BEST_HP)

    # Ensure the encoder is on the correct device for evaluation
    final_encoder = final_encoder.to(DEVICE)

    # Evaluate classifiers on the latent space
    classification_results = evaluate_classifiers(final_encoder, train_X, train_Y, test_X, test_Y, device=DEVICE, seed=SEED)

    print("\n--- Final Run Finished ---")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   Validation loss did not improve for 28 epoch(s).
# Epoch 1765/4000 [0.72s] - Train Loss: 75306.75 (Recon: 69980.39, KLD: 106.53, Beta: 50.00) | Val Loss: 74861.84 (Recon: 69478.05, KLD: 107.68)
#   Validation loss did not improve for 29 epoch(s).
# Epoch 1766/4000 [0.76s] - Train Loss: 75367.89 (Recon: 69959.64, KLD: 108.16, Beta: 50.00) | Val Loss: 75047.98 (Recon: 69577.55, KLD: 109.41)
#   Validation loss did not improve for 30 epoch(s).
# Epoch 1767/4000 [0.71s] - Train Loss: 75299.74 (Recon: 69799.59, KLD: 110.00, Beta: 50.00) | Val Loss: 75178.19 (Recon: 69782.30, KLD: 107.92)
#   Validation loss did not improve for 31 epoch(s).
# Epoch 1768/4000 [0.71s] - Train Loss: 75325.19 (Recon: 69913.61, KLD: 108.23, Beta: 50.00) | Val Loss: 75001.81 (Recon: 69580.44, KLD: 108.43)
#   Validation loss did not improve for 32 epoch(s).
# Epoch 1769/4000 [0.62s] - Train Loss: 75470.27 (Recon: 70019.67, KLD: 109.01, Beta: 50.00) | Val Loss: 75219.88 (Recon: 69804.69, KLD: 108.30)
#   Validation loss did not improve for 33 epoch(s).
# Epoch 1770/4000 [0.61s] - Train Loss: 75293.66 (Recon: 69921.10, KLD: 107.45, Beta: 50.00) | Val Loss: 75263.36 (Recon: 69932.86, KLD: 106.61)
#   Validation loss did not improve for 34 epoch(s).
# Epoch 1771/4000 [0.61s] - Train Loss: 75348.91 (Recon: 69896.93, KLD: 109.04, Beta: 50.00) | Val Loss: 74868.45 (Recon: 69448.55, KLD: 108.40)
#   Validation loss did not improve for 35 epoch(s).
# Epoch 1772/4000 [0.61s] - Train Loss: 75180.62 (Recon: 69802.95, KLD: 107.55, Beta: 50.00) | Val Loss: 74942.00 (Recon: 69646.10, KLD: 105.92)
#   Validation loss did not improve for 36 epoch(s).
# Epoch 1773/4000 [0.62s] - Train Loss: 75265.86 (Recon: 69923.02, KLD: 106.86, Beta: 50.00) | Val Loss: 74958.84 (Recon: 69449.77, KLD: 110.18)
#   Validation loss did not improve for 37 epoch(s).
# Epoch 1774/4000 [0.62s] - Train Loss: 75297.56 (Recon: 69869.67, KLD: 108.56, Beta: 50.00) | Val Loss: 74857.98 (Recon: 69577.91, KLD: 105.60)
#   Validation loss did not improve for 38 epoch(s).
# Epoch 1775/4000 [0.61s] - Train Loss: 75416.43 (Recon: 70095.04, KLD: 106.43, Beta: 50.00) | Val Loss: 74801.54 (Recon: 69340.57, KLD: 109.22)
#   ** New best validation loss: 74801.5391. Saving model state. **
# Epoch 1776/4000 [0.62s] - Train Loss: 75285.04 (Recon: 69831.94, KLD: 109.06, Beta: 50.00) | Val Loss: 74860.46 (Recon: 69512.84, KLD: 106.95)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1777/4000 [0.61s] - Train Loss: 75302.44 (Recon: 69989.49, KLD: 106.26, Beta: 50.00) | Val Loss: 74999.90 (Recon: 69634.80, KLD: 107.30)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1778/4000 [0.61s] - Train Loss: 75378.03 (Recon: 69926.20, KLD: 109.04, Beta: 50.00) | Val Loss: 74811.11 (Recon: 69391.27, KLD: 108.40)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1779/4000 [0.61s] - Train Loss: 75233.46 (Recon: 69819.71, KLD: 108.28, Beta: 50.00) | Val Loss: 74775.69 (Recon: 69336.62, KLD: 108.78)
#   ** New best validation loss: 74775.6875. Saving model state. **
# Epoch 1780/4000 [0.61s] - Train Loss: 75278.31 (Recon: 69865.81, KLD: 108.25, Beta: 50.00) | Val Loss: 74972.08 (Recon: 69543.47, KLD: 108.57)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1781/4000 [0.61s] - Train Loss: 75315.56 (Recon: 69792.73, KLD: 110.46, Beta: 50.00) | Val Loss: 74966.34 (Recon: 69391.22, KLD: 111.50)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1782/4000 [0.62s] - Train Loss: 75180.65 (Recon: 69650.22, KLD: 110.61, Beta: 50.00) | Val Loss: 74866.19 (Recon: 69485.13, KLD: 107.62)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1783/4000 [0.64s] - Train Loss: 75306.94 (Recon: 69857.91, KLD: 108.98, Beta: 50.00) | Val Loss: 74948.57 (Recon: 69458.81, KLD: 109.80)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1784/4000 [0.71s] - Train Loss: 75144.52 (Recon: 69715.91, KLD: 108.57, Beta: 50.00) | Val Loss: 74800.34 (Recon: 69395.05, KLD: 108.11)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1785/4000 [0.70s] - Train Loss: 75207.39 (Recon: 69762.45, KLD: 108.90, Beta: 50.00) | Val Loss: 74884.27 (Recon: 69404.25, KLD: 109.60)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1786/4000 [0.73s] - Train Loss: 75285.06 (Recon: 69851.08, KLD: 108.68, Beta: 50.00) | Val Loss: 74902.95 (Recon: 69527.27, KLD: 107.51)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1787/4000 [0.72s] - Train Loss: 75184.92 (Recon: 69802.54, KLD: 107.65, Beta: 50.00) | Val Loss: 74948.04 (Recon: 69529.20, KLD: 108.38)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1788/4000 [0.64s] - Train Loss: 75457.42 (Recon: 70042.80, KLD: 108.29, Beta: 50.00) | Val Loss: 74926.41 (Recon: 69592.61, KLD: 106.68)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1789/4000 [0.61s] - Train Loss: 75151.43 (Recon: 69834.99, KLD: 106.33, Beta: 50.00) | Val Loss: 74925.13 (Recon: 69508.02, KLD: 108.34)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1790/4000 [0.63s] - Train Loss: 75171.26 (Recon: 69716.53, KLD: 109.09, Beta: 50.00) | Val Loss: 74859.88 (Recon: 69402.69, KLD: 109.14)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1791/4000 [0.61s] - Train Loss: 75041.86 (Recon: 69583.90, KLD: 109.16, Beta: 50.00) | Val Loss: 74875.30 (Recon: 69387.84, KLD: 109.75)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1792/4000 [0.61s] - Train Loss: 75128.68 (Recon: 69680.41, KLD: 108.97, Beta: 50.00) | Val Loss: 74593.82 (Recon: 69146.17, KLD: 108.95)
#   ** New best validation loss: 74593.8203. Saving model state. **
# Epoch 1793/4000 [0.61s] - Train Loss: 75038.60 (Recon: 69600.17, KLD: 108.77, Beta: 50.00) | Val Loss: 74905.38 (Recon: 69487.20, KLD: 108.36)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1794/4000 [0.61s] - Train Loss: 74953.47 (Recon: 69539.82, KLD: 108.27, Beta: 50.00) | Val Loss: 74846.95 (Recon: 69404.88, KLD: 108.84)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1795/4000 [0.61s] - Train Loss: 75012.90 (Recon: 69614.28, KLD: 107.97, Beta: 50.00) | Val Loss: 75063.20 (Recon: 69626.15, KLD: 108.74)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1796/4000 [0.61s] - Train Loss: 75197.34 (Recon: 69790.33, KLD: 108.14, Beta: 50.00) | Val Loss: 75021.41 (Recon: 69554.52, KLD: 109.34)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1797/4000 [0.63s] - Train Loss: 75017.13 (Recon: 69567.26, KLD: 109.00, Beta: 50.00) | Val Loss: 75009.02 (Recon: 69575.40, KLD: 108.67)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1798/4000 [0.61s] - Train Loss: 75080.73 (Recon: 69675.13, KLD: 108.11, Beta: 50.00) | Val Loss: 74664.68 (Recon: 69256.52, KLD: 108.16)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1799/4000 [0.61s] - Train Loss: 75328.07 (Recon: 69856.65, KLD: 109.43, Beta: 50.00) | Val Loss: 74722.99 (Recon: 69291.87, KLD: 108.62)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1800/4000 [0.61s] - Train Loss: 75114.05 (Recon: 69693.89, KLD: 108.40, Beta: 50.00) | Val Loss: 75001.59 (Recon: 69585.19, KLD: 108.33)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1801/4000 [0.61s] - Train Loss: 75097.70 (Recon: 69601.46, KLD: 109.92, Beta: 50.00) | Val Loss: 74652.72 (Recon: 69164.52, KLD: 109.76)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1802/4000 [0.61s] - Train Loss: 75066.16 (Recon: 69633.88, KLD: 108.65, Beta: 50.00) | Val Loss: 74680.86 (Recon: 69274.27, KLD: 108.13)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1803/4000 [0.66s] - Train Loss: 75258.80 (Recon: 69775.62, KLD: 109.66, Beta: 50.00) | Val Loss: 74900.23 (Recon: 69339.82, KLD: 111.21)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1804/4000 [0.72s] - Train Loss: 75075.87 (Recon: 69612.67, KLD: 109.26, Beta: 50.00) | Val Loss: 74766.49 (Recon: 69391.54, KLD: 107.50)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1805/4000 [0.72s] - Train Loss: 75213.48 (Recon: 69804.09, KLD: 108.19, Beta: 50.00) | Val Loss: 74781.64 (Recon: 69269.29, KLD: 110.25)
#   Validation loss did not improve for 13 epoch(s).
# Epoch 1806/4000 [0.71s] - Train Loss: 74954.35 (Recon: 69501.72, KLD: 109.05, Beta: 50.00) | Val Loss: 74472.02 (Recon: 69117.58, KLD: 107.09)
#   ** New best validation loss: 74472.0156. Saving model state. **
# Epoch 1807/4000 [0.69s] - Train Loss: 75276.47 (Recon: 69878.09, KLD: 107.97, Beta: 50.00) | Val Loss: 74836.03 (Recon: 69317.91, KLD: 110.36)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1808/4000 [0.61s] - Train Loss: 75184.28 (Recon: 69674.13, KLD: 110.20, Beta: 50.00) | Val Loss: 74661.38 (Recon: 69184.44, KLD: 109.54)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1809/4000 [0.61s] - Train Loss: 75145.23 (Recon: 69676.69, KLD: 109.37, Beta: 50.00) | Val Loss: 74672.37 (Recon: 69150.14, KLD: 110.44)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1810/4000 [0.61s] - Train Loss: 75228.69 (Recon: 69626.72, KLD: 112.04, Beta: 50.00) | Val Loss: 74699.98 (Recon: 69136.47, KLD: 111.27)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1811/4000 [0.61s] - Train Loss: 75066.18 (Recon: 69568.17, KLD: 109.96, Beta: 50.00) | Val Loss: 74753.03 (Recon: 69364.84, KLD: 107.76)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1812/4000 [0.63s] - Train Loss: 74838.22 (Recon: 69435.37, KLD: 108.06, Beta: 50.00) | Val Loss: 74796.55 (Recon: 69276.70, KLD: 110.40)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1813/4000 [0.62s] - Train Loss: 74985.99 (Recon: 69499.54, KLD: 109.73, Beta: 50.00) | Val Loss: 74753.84 (Recon: 69342.20, KLD: 108.23)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1814/4000 [0.61s] - Train Loss: 74957.52 (Recon: 69604.02, KLD: 107.07, Beta: 50.00) | Val Loss: 74627.84 (Recon: 69275.78, KLD: 107.04)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1815/4000 [0.61s] - Train Loss: 75135.74 (Recon: 69720.76, KLD: 108.30, Beta: 50.00) | Val Loss: 74733.27 (Recon: 69151.96, KLD: 111.63)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1816/4000 [0.61s] - Train Loss: 75147.27 (Recon: 69640.22, KLD: 110.14, Beta: 50.00) | Val Loss: 74756.22 (Recon: 69335.01, KLD: 108.42)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1817/4000 [0.62s] - Train Loss: 75012.06 (Recon: 69582.73, KLD: 108.59, Beta: 50.00) | Val Loss: 74560.86 (Recon: 69016.93, KLD: 110.88)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1818/4000 [0.61s] - Train Loss: 74821.25 (Recon: 69286.13, KLD: 110.70, Beta: 50.00) | Val Loss: 74921.80 (Recon: 69498.98, KLD: 108.46)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1819/4000 [0.61s] - Train Loss: 74938.63 (Recon: 69539.45, KLD: 107.98, Beta: 50.00) | Val Loss: 74744.47 (Recon: 69250.55, KLD: 109.88)
#   Validation loss did not improve for 13 epoch(s).
# Epoch 1820/4000 [0.61s] - Train Loss: 75096.25 (Recon: 69536.46, KLD: 111.20, Beta: 50.00) | Val Loss: 74712.10 (Recon: 69156.37, KLD: 111.11)
#   Validation loss did not improve for 14 epoch(s).
# Epoch 1821/4000 [0.61s] - Train Loss: 75162.24 (Recon: 69737.48, KLD: 108.50, Beta: 50.00) | Val Loss: 74537.97 (Recon: 69080.88, KLD: 109.14)
#   Validation loss did not improve for 15 epoch(s).
# Epoch 1822/4000 [0.63s] - Train Loss: 75064.60 (Recon: 69531.54, KLD: 110.66, Beta: 50.00) | Val Loss: 74446.71 (Recon: 68916.02, KLD: 110.61)
#   ** New best validation loss: 74446.7109. Saving model state. **
# Epoch 1823/4000 [0.66s] - Train Loss: 75057.67 (Recon: 69567.88, KLD: 109.80, Beta: 50.00) | Val Loss: 74540.75 (Recon: 69040.03, KLD: 110.01)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1824/4000 [0.71s] - Train Loss: 75149.37 (Recon: 69627.73, KLD: 110.43, Beta: 50.00) | Val Loss: 74837.47 (Recon: 69334.70, KLD: 110.06)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1825/4000 [0.70s] - Train Loss: 75159.93 (Recon: 69703.69, KLD: 109.12, Beta: 50.00) | Val Loss: 74584.07 (Recon: 69136.09, KLD: 108.96)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1826/4000 [0.71s] - Train Loss: 74866.30 (Recon: 69420.13, KLD: 108.92, Beta: 50.00) | Val Loss: 74722.59 (Recon: 69283.27, KLD: 108.79)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1827/4000 [0.68s] - Train Loss: 75002.82 (Recon: 69535.07, KLD: 109.36, Beta: 50.00) | Val Loss: 74846.88 (Recon: 69362.66, KLD: 109.68)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1828/4000 [0.61s] - Train Loss: 74932.16 (Recon: 69442.49, KLD: 109.79, Beta: 50.00) | Val Loss: 74637.53 (Recon: 69041.47, KLD: 111.92)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1829/4000 [0.61s] - Train Loss: 74860.17 (Recon: 69306.60, KLD: 111.07, Beta: 50.00) | Val Loss: 74525.56 (Recon: 68997.09, KLD: 110.57)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1830/4000 [0.61s] - Train Loss: 74844.95 (Recon: 69372.96, KLD: 109.44, Beta: 50.00) | Val Loss: 74634.48 (Recon: 69201.27, KLD: 108.66)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1831/4000 [0.61s] - Train Loss: 75091.85 (Recon: 69651.85, KLD: 108.80, Beta: 50.00) | Val Loss: 74679.12 (Recon: 69241.70, KLD: 108.75)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1832/4000 [0.61s] - Train Loss: 74952.48 (Recon: 69534.41, KLD: 108.36, Beta: 50.00) | Val Loss: 74883.18 (Recon: 69421.02, KLD: 109.24)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1833/4000 [0.63s] - Train Loss: 74830.09 (Recon: 69369.78, KLD: 109.21, Beta: 50.00) | Val Loss: 74497.74 (Recon: 69020.04, KLD: 109.55)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1834/4000 [0.61s] - Train Loss: 74997.68 (Recon: 69518.40, KLD: 109.59, Beta: 50.00) | Val Loss: 74572.66 (Recon: 69036.77, KLD: 110.72)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1835/4000 [0.61s] - Train Loss: 74968.25 (Recon: 69464.77, KLD: 110.07, Beta: 50.00) | Val Loss: 74650.22 (Recon: 69195.79, KLD: 109.09)
#   Validation loss did not improve for 13 epoch(s).
# Epoch 1836/4000 [0.61s] - Train Loss: 74890.24 (Recon: 69384.97, KLD: 110.11, Beta: 50.00) | Val Loss: 74373.72 (Recon: 68806.27, KLD: 111.35)
#   ** New best validation loss: 74373.7188. Saving model state. **
# Epoch 1837/4000 [0.61s] - Train Loss: 74840.85 (Recon: 69357.24, KLD: 109.67, Beta: 50.00) | Val Loss: 74776.03 (Recon: 69251.01, KLD: 110.50)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1838/4000 [0.61s] - Train Loss: 74870.89 (Recon: 69293.43, KLD: 111.55, Beta: 50.00) | Val Loss: 74673.27 (Recon: 69041.97, KLD: 112.63)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1839/4000 [0.63s] - Train Loss: 74935.17 (Recon: 69384.85, KLD: 111.01, Beta: 50.00) | Val Loss: 74203.98 (Recon: 68698.08, KLD: 110.12)
#   ** New best validation loss: 74203.9766. Saving model state. **
# Epoch 1840/4000 [0.61s] - Train Loss: 74743.29 (Recon: 69243.38, KLD: 110.00, Beta: 50.00) | Val Loss: 74449.52 (Recon: 68927.77, KLD: 110.43)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1841/4000 [0.61s] - Train Loss: 75005.93 (Recon: 69507.19, KLD: 109.97, Beta: 50.00) | Val Loss: 74663.56 (Recon: 69252.63, KLD: 108.22)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1842/4000 [0.66s] - Train Loss: 74912.52 (Recon: 69456.93, KLD: 109.11, Beta: 50.00) | Val Loss: 74557.10 (Recon: 68972.39, KLD: 111.69)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1843/4000 [0.71s] - Train Loss: 74903.14 (Recon: 69332.35, KLD: 111.42, Beta: 50.00) | Val Loss: 74559.22 (Recon: 69035.66, KLD: 110.47)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1844/4000 [0.70s] - Train Loss: 74794.32 (Recon: 69280.86, KLD: 110.27, Beta: 50.00) | Val Loss: 74571.37 (Recon: 68918.73, KLD: 113.05)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1845/4000 [0.72s] - Train Loss: 74898.46 (Recon: 69331.18, KLD: 111.35, Beta: 50.00) | Val Loss: 74643.79 (Recon: 69184.76, KLD: 109.18)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1846/4000 [0.73s] - Train Loss: 74867.54 (Recon: 69448.33, KLD: 108.38, Beta: 50.00) | Val Loss: 74357.41 (Recon: 68810.74, KLD: 110.93)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1847/4000 [0.66s] - Train Loss: 74860.11 (Recon: 69277.73, KLD: 111.65, Beta: 50.00) | Val Loss: 74682.41 (Recon: 69204.30, KLD: 109.56)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1848/4000 [0.61s] - Train Loss: 74858.56 (Recon: 69460.64, KLD: 107.96, Beta: 50.00) | Val Loss: 74784.48 (Recon: 69305.87, KLD: 109.57)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1849/4000 [0.61s] - Train Loss: 75050.59 (Recon: 69513.61, KLD: 110.74, Beta: 50.00) | Val Loss: 74504.76 (Recon: 68961.57, KLD: 110.86)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1850/4000 [0.61s] - Train Loss: 74968.03 (Recon: 69474.59, KLD: 109.87, Beta: 50.00) | Val Loss: 74712.73 (Recon: 69164.41, KLD: 110.97)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1851/4000 [0.61s] - Train Loss: 74829.48 (Recon: 69227.17, KLD: 112.05, Beta: 50.00) | Val Loss: 74580.26 (Recon: 68972.27, KLD: 112.16)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1852/4000 [0.61s] - Train Loss: 74786.38 (Recon: 69253.48, KLD: 110.66, Beta: 50.00) | Val Loss: 74682.77 (Recon: 69296.63, KLD: 107.72)
#   Validation loss did not improve for 13 epoch(s).
# Epoch 1853/4000 [0.62s] - Train Loss: 74780.57 (Recon: 69381.40, KLD: 107.98, Beta: 50.00) | Val Loss: 74704.17 (Recon: 69213.97, KLD: 109.80)
#   Validation loss did not improve for 14 epoch(s).
# Epoch 1854/4000 [0.62s] - Train Loss: 74860.64 (Recon: 69388.99, KLD: 109.43, Beta: 50.00) | Val Loss: 74410.84 (Recon: 69027.19, KLD: 107.67)
#   Validation loss did not improve for 15 epoch(s).
# Epoch 1855/4000 [0.61s] - Train Loss: 74716.24 (Recon: 69251.11, KLD: 109.30, Beta: 50.00) | Val Loss: 74488.66 (Recon: 68977.95, KLD: 110.21)
#   Validation loss did not improve for 16 epoch(s).
# Epoch 1856/4000 [0.61s] - Train Loss: 74850.89 (Recon: 69369.10, KLD: 109.64, Beta: 50.00) | Val Loss: 74348.48 (Recon: 68851.02, KLD: 109.95)
#   Validation loss did not improve for 17 epoch(s).
# Epoch 1857/4000 [0.61s] - Train Loss: 74808.67 (Recon: 69301.35, KLD: 110.15, Beta: 50.00) | Val Loss: 74459.52 (Recon: 68802.64, KLD: 113.14)
#   Validation loss did not improve for 18 epoch(s).
# Epoch 1858/4000 [0.61s] - Train Loss: 74853.20 (Recon: 69209.71, KLD: 112.87, Beta: 50.00) | Val Loss: 74703.95 (Recon: 69185.02, KLD: 110.38)
#   Validation loss did not improve for 19 epoch(s).
# Epoch 1859/4000 [0.61s] - Train Loss: 74732.28 (Recon: 69219.25, KLD: 110.26, Beta: 50.00) | Val Loss: 74372.69 (Recon: 68770.90, KLD: 112.04)
#   Validation loss did not improve for 20 epoch(s).
# Epoch 1860/4000 [0.61s] - Train Loss: 74703.14 (Recon: 69072.73, KLD: 112.61, Beta: 50.00) | Val Loss: 74459.88 (Recon: 68980.20, KLD: 109.59)
#   Validation loss did not improve for 21 epoch(s).
# Epoch 1861/4000 [0.61s] - Train Loss: 74843.97 (Recon: 69374.49, KLD: 109.39, Beta: 50.00) | Val Loss: 74531.13 (Recon: 68989.38, KLD: 110.84)
#   Validation loss did not improve for 22 epoch(s).
# Epoch 1862/4000 [0.61s] - Train Loss: 74751.62 (Recon: 69148.64, KLD: 112.06, Beta: 50.00) | Val Loss: 74760.20 (Recon: 69168.61, KLD: 111.83)
#   Validation loss did not improve for 23 epoch(s).
# Epoch 1863/4000 [0.64s] - Train Loss: 74730.93 (Recon: 69224.91, KLD: 110.12, Beta: 50.00) | Val Loss: 74564.82 (Recon: 69141.13, KLD: 108.47)
#   Validation loss did not improve for 24 epoch(s).
# Epoch 1864/4000 [0.74s] - Train Loss: 74882.28 (Recon: 69443.65, KLD: 108.77, Beta: 50.00) | Val Loss: 74603.32 (Recon: 69047.27, KLD: 111.12)
#   Validation loss did not improve for 25 epoch(s).
# Epoch 1865/4000 [0.72s] - Train Loss: 74790.15 (Recon: 69270.06, KLD: 110.40, Beta: 50.00) | Val Loss: 74536.23 (Recon: 69111.09, KLD: 108.50)
#   Validation loss did not improve for 26 epoch(s).
# Epoch 1866/4000 [0.71s] - Train Loss: 74747.68 (Recon: 69296.09, KLD: 109.03, Beta: 50.00) | Val Loss: 74179.45 (Recon: 68587.32, KLD: 111.84)
#   ** New best validation loss: 74179.4531. Saving model state. **
# Epoch 1867/4000 [0.66s] - Train Loss: 74807.36 (Recon: 69196.64, KLD: 112.21, Beta: 50.00) | Val Loss: 74351.19 (Recon: 68793.81, KLD: 111.15)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1868/4000 [0.61s] - Train Loss: 74830.79 (Recon: 69258.65, KLD: 111.44, Beta: 50.00) | Val Loss: 74438.16 (Recon: 68814.84, KLD: 112.47)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1869/4000 [0.61s] - Train Loss: 74808.84 (Recon: 69139.21, KLD: 113.39, Beta: 50.00) | Val Loss: 74451.45 (Recon: 68787.05, KLD: 113.29)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1870/4000 [0.61s] - Train Loss: 74749.95 (Recon: 69116.10, KLD: 112.68, Beta: 50.00) | Val Loss: 74639.58 (Recon: 69100.95, KLD: 110.77)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1871/4000 [0.61s] - Train Loss: 74899.46 (Recon: 69373.50, KLD: 110.52, Beta: 50.00) | Val Loss: 74391.24 (Recon: 68840.57, KLD: 111.01)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1872/4000 [0.61s] - Train Loss: 74836.89 (Recon: 69325.80, KLD: 110.22, Beta: 50.00) | Val Loss: 74497.52 (Recon: 69066.77, KLD: 108.61)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1873/4000 [0.61s] - Train Loss: 74725.03 (Recon: 69218.96, KLD: 110.12, Beta: 50.00) | Val Loss: 74225.38 (Recon: 68557.27, KLD: 113.36)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1874/4000 [0.62s] - Train Loss: 74786.00 (Recon: 69155.70, KLD: 112.61, Beta: 50.00) | Val Loss: 74389.02 (Recon: 68874.32, KLD: 110.29)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1875/4000 [0.61s] - Train Loss: 74845.36 (Recon: 69329.14, KLD: 110.32, Beta: 50.00) | Val Loss: 74172.14 (Recon: 68559.15, KLD: 112.26)
#   ** New best validation loss: 74172.1406. Saving model state. **
# Epoch 1876/4000 [0.61s] - Train Loss: 74973.77 (Recon: 69226.20, KLD: 114.95, Beta: 50.00) | Val Loss: 74819.43 (Recon: 69127.96, KLD: 113.83)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1877/4000 [0.61s] - Train Loss: 74821.07 (Recon: 69225.66, KLD: 111.91, Beta: 50.00) | Val Loss: 74654.45 (Recon: 69162.77, KLD: 109.83)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1878/4000 [0.64s] - Train Loss: 74757.80 (Recon: 69212.63, KLD: 110.90, Beta: 50.00) | Val Loss: 74238.78 (Recon: 68605.79, KLD: 112.66)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1879/4000 [0.61s] - Train Loss: 74817.44 (Recon: 69251.27, KLD: 111.32, Beta: 50.00) | Val Loss: 74662.16 (Recon: 69156.68, KLD: 110.11)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1880/4000 [0.62s] - Train Loss: 74837.95 (Recon: 69277.19, KLD: 111.22, Beta: 50.00) | Val Loss: 74483.24 (Recon: 68964.81, KLD: 110.37)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1881/4000 [0.61s] - Train Loss: 74737.17 (Recon: 69303.91, KLD: 108.67, Beta: 50.00) | Val Loss: 74340.52 (Recon: 68824.50, KLD: 110.32)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1882/4000 [0.61s] - Train Loss: 74609.97 (Recon: 69022.19, KLD: 111.76, Beta: 50.00) | Val Loss: 74137.98 (Recon: 68541.53, KLD: 111.93)
#   ** New best validation loss: 74137.9766. Saving model state. **
# Epoch 1883/4000 [0.71s] - Train Loss: 74913.96 (Recon: 69337.12, KLD: 111.54, Beta: 50.00) | Val Loss: 74461.87 (Recon: 68892.80, KLD: 111.38)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1884/4000 [0.69s] - Train Loss: 74615.02 (Recon: 68977.08, KLD: 112.76, Beta: 50.00) | Val Loss: 74336.08 (Recon: 68662.62, KLD: 113.47)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1885/4000 [0.74s] - Train Loss: 74760.29 (Recon: 69108.37, KLD: 113.04, Beta: 50.00) | Val Loss: 74267.84 (Recon: 68764.15, KLD: 110.07)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1886/4000 [0.70s] - Train Loss: 74636.14 (Recon: 69172.23, KLD: 109.28, Beta: 50.00) | Val Loss: 74477.34 (Recon: 68976.02, KLD: 110.03)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1887/4000 [0.63s] - Train Loss: 74647.24 (Recon: 69105.55, KLD: 110.83, Beta: 50.00) | Val Loss: 74206.03 (Recon: 68728.12, KLD: 109.56)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1888/4000 [0.63s] - Train Loss: 74711.52 (Recon: 69193.96, KLD: 110.35, Beta: 50.00) | Val Loss: 74453.24 (Recon: 68957.88, KLD: 109.91)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1889/4000 [0.62s] - Train Loss: 74696.60 (Recon: 69174.06, KLD: 110.45, Beta: 50.00) | Val Loss: 74354.36 (Recon: 68821.73, KLD: 110.65)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1890/4000 [0.61s] - Train Loss: 74754.87 (Recon: 69206.40, KLD: 110.97, Beta: 50.00) | Val Loss: 74326.41 (Recon: 68760.42, KLD: 111.32)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1891/4000 [0.61s] - Train Loss: 74658.84 (Recon: 69039.70, KLD: 112.38, Beta: 50.00) | Val Loss: 74418.51 (Recon: 68876.87, KLD: 110.83)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1892/4000 [0.61s] - Train Loss: 74590.84 (Recon: 68987.12, KLD: 112.07, Beta: 50.00) | Val Loss: 74124.38 (Recon: 68447.66, KLD: 113.53)
#   ** New best validation loss: 74124.3750. Saving model state. **
# Epoch 1893/4000 [0.61s] - Train Loss: 74694.58 (Recon: 69036.17, KLD: 113.17, Beta: 50.00) | Val Loss: 74222.74 (Recon: 68636.68, KLD: 111.72)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1894/4000 [0.61s] - Train Loss: 74594.36 (Recon: 68999.00, KLD: 111.91, Beta: 50.00) | Val Loss: 74262.45 (Recon: 68650.97, KLD: 112.23)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1895/4000 [0.62s] - Train Loss: 74696.46 (Recon: 69044.27, KLD: 113.04, Beta: 50.00) | Val Loss: 74315.99 (Recon: 68730.51, KLD: 111.71)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1896/4000 [0.62s] - Train Loss: 74756.35 (Recon: 69183.71, KLD: 111.45, Beta: 50.00) | Val Loss: 74571.53 (Recon: 68976.78, KLD: 111.89)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1897/4000 [0.61s] - Train Loss: 74550.47 (Recon: 69002.79, KLD: 110.95, Beta: 50.00) | Val Loss: 74237.48 (Recon: 68712.54, KLD: 110.50)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1898/4000 [0.61s] - Train Loss: 74546.82 (Recon: 68987.23, KLD: 111.19, Beta: 50.00) | Val Loss: 74325.67 (Recon: 68674.06, KLD: 113.03)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1899/4000 [0.62s] - Train Loss: 74532.51 (Recon: 68888.98, KLD: 112.87, Beta: 50.00) | Val Loss: 74342.31 (Recon: 68780.50, KLD: 111.24)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1900/4000 [0.61s] - Train Loss: 74509.17 (Recon: 68968.49, KLD: 110.81, Beta: 50.00) | Val Loss: 74399.56 (Recon: 68877.27, KLD: 110.45)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1901/4000 [0.61s] - Train Loss: 74379.48 (Recon: 68844.26, KLD: 110.70, Beta: 50.00) | Val Loss: 74047.16 (Recon: 68443.51, KLD: 112.07)
#   ** New best validation loss: 74047.1562. Saving model state. **
# Epoch 1902/4000 [0.74s] - Train Loss: 74529.50 (Recon: 68955.15, KLD: 111.49, Beta: 50.00) | Val Loss: 74208.62 (Recon: 68679.35, KLD: 110.59)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1903/4000 [0.72s] - Train Loss: 74549.34 (Recon: 69035.82, KLD: 110.27, Beta: 50.00) | Val Loss: 74042.53 (Recon: 68448.09, KLD: 111.89)
#   ** New best validation loss: 74042.5312. Saving model state. **
# Epoch 1904/4000 [0.71s] - Train Loss: 74688.72 (Recon: 69064.69, KLD: 112.48, Beta: 50.00) | Val Loss: 74273.15 (Recon: 68708.52, KLD: 111.29)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1905/4000 [0.70s] - Train Loss: 74502.52 (Recon: 68937.42, KLD: 111.30, Beta: 50.00) | Val Loss: 74245.33 (Recon: 68645.58, KLD: 112.00)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1906/4000 [0.61s] - Train Loss: 74581.76 (Recon: 68961.48, KLD: 112.41, Beta: 50.00) | Val Loss: 74359.09 (Recon: 68824.07, KLD: 110.70)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1907/4000 [0.61s] - Train Loss: 74502.41 (Recon: 68968.76, KLD: 110.67, Beta: 50.00) | Val Loss: 74117.40 (Recon: 68560.62, KLD: 111.14)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1908/4000 [0.61s] - Train Loss: 74508.52 (Recon: 68908.30, KLD: 112.00, Beta: 50.00) | Val Loss: 74048.92 (Recon: 68486.45, KLD: 111.25)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1909/4000 [0.61s] - Train Loss: 74475.39 (Recon: 68879.13, KLD: 111.93, Beta: 50.00) | Val Loss: 74356.13 (Recon: 68719.84, KLD: 112.73)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1910/4000 [0.62s] - Train Loss: 74710.26 (Recon: 69056.94, KLD: 113.07, Beta: 50.00) | Val Loss: 74276.33 (Recon: 68731.62, KLD: 110.89)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1911/4000 [0.61s] - Train Loss: 74451.32 (Recon: 68813.54, KLD: 112.76, Beta: 50.00) | Val Loss: 74058.90 (Recon: 68356.17, KLD: 114.05)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1912/4000 [0.61s] - Train Loss: 74711.16 (Recon: 69070.45, KLD: 112.81, Beta: 50.00) | Val Loss: 74545.58 (Recon: 69073.83, KLD: 109.44)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1913/4000 [0.61s] - Train Loss: 74395.78 (Recon: 68872.14, KLD: 110.47, Beta: 50.00) | Val Loss: 74322.68 (Recon: 68718.32, KLD: 112.09)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1914/4000 [0.61s] - Train Loss: 74577.40 (Recon: 68975.28, KLD: 112.04, Beta: 50.00) | Val Loss: 74183.68 (Recon: 68526.31, KLD: 113.15)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1915/4000 [0.63s] - Train Loss: 74552.73 (Recon: 68917.74, KLD: 112.70, Beta: 50.00) | Val Loss: 74569.42 (Recon: 68990.09, KLD: 111.59)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1916/4000 [0.62s] - Train Loss: 74651.05 (Recon: 69021.02, KLD: 112.60, Beta: 50.00) | Val Loss: 74133.91 (Recon: 68486.50, KLD: 112.95)
#   Validation loss did not improve for 13 epoch(s).
# Epoch 1917/4000 [0.61s] - Train Loss: 74574.78 (Recon: 68874.65, KLD: 114.00, Beta: 50.00) | Val Loss: 74047.38 (Recon: 68418.38, KLD: 112.58)
#   Validation loss did not improve for 14 epoch(s).
# Epoch 1918/4000 [0.61s] - Train Loss: 74383.38 (Recon: 68747.52, KLD: 112.72, Beta: 50.00) | Val Loss: 74359.62 (Recon: 68740.55, KLD: 112.38)
#   Validation loss did not improve for 15 epoch(s).
# Epoch 1919/4000 [0.61s] - Train Loss: 74533.20 (Recon: 68857.26, KLD: 113.52, Beta: 50.00) | Val Loss: 74273.70 (Recon: 68698.32, KLD: 111.51)
#   Validation loss did not improve for 16 epoch(s).
# Epoch 1920/4000 [0.62s] - Train Loss: 74398.96 (Recon: 68946.53, KLD: 109.05, Beta: 50.00) | Val Loss: 74427.69 (Recon: 68994.39, KLD: 108.67)
#   Validation loss did not improve for 17 epoch(s).
# Epoch 1921/4000 [0.64s] - Train Loss: 74592.52 (Recon: 69083.66, KLD: 110.18, Beta: 50.00) | Val Loss: 74365.78 (Recon: 68701.91, KLD: 113.28)
#   Validation loss did not improve for 18 epoch(s).
# Epoch 1922/4000 [0.68s] - Train Loss: 74487.62 (Recon: 68874.36, KLD: 112.27, Beta: 50.00) | Val Loss: 74353.00 (Recon: 68763.88, KLD: 111.78)
#   Validation loss did not improve for 19 epoch(s).
# Epoch 1923/4000 [0.70s] - Train Loss: 74478.63 (Recon: 68886.15, KLD: 111.85, Beta: 50.00) | Val Loss: 74359.13 (Recon: 68544.73, KLD: 116.29)
#   Validation loss did not improve for 20 epoch(s).
# Epoch 1924/4000 [0.73s] - Train Loss: 74512.56 (Recon: 68749.77, KLD: 115.26, Beta: 50.00) | Val Loss: 74236.88 (Recon: 68684.23, KLD: 111.05)
#   Validation loss did not improve for 21 epoch(s).
# Epoch 1925/4000 [0.73s] - Train Loss: 74620.76 (Recon: 69039.20, KLD: 111.63, Beta: 50.00) | Val Loss: 74353.13 (Recon: 68609.20, KLD: 114.88)
#   Validation loss did not improve for 22 epoch(s).
# Epoch 1926/4000 [0.69s] - Train Loss: 74517.96 (Recon: 68802.42, KLD: 114.31, Beta: 50.00) | Val Loss: 74098.41 (Recon: 68579.05, KLD: 110.39)
#   Validation loss did not improve for 23 epoch(s).
# Epoch 1927/4000 [0.61s] - Train Loss: 74447.40 (Recon: 68949.70, KLD: 109.95, Beta: 50.00) | Val Loss: 74132.30 (Recon: 68504.45, KLD: 112.56)
#   Validation loss did not improve for 24 epoch(s).
# Epoch 1928/4000 [0.62s] - Train Loss: 74358.17 (Recon: 68744.87, KLD: 112.27, Beta: 50.00) | Val Loss: 74141.07 (Recon: 68562.89, KLD: 111.56)
#   Validation loss did not improve for 25 epoch(s).
# Epoch 1929/4000 [0.62s] - Train Loss: 74329.66 (Recon: 68758.33, KLD: 111.43, Beta: 50.00) | Val Loss: 74097.34 (Recon: 68469.28, KLD: 112.56)
#   Validation loss did not improve for 26 epoch(s).
# Epoch 1930/4000 [0.61s] - Train Loss: 74459.68 (Recon: 68754.70, KLD: 114.10, Beta: 50.00) | Val Loss: 74300.55 (Recon: 68633.15, KLD: 113.35)
#   Validation loss did not improve for 27 epoch(s).
# Epoch 1931/4000 [0.61s] - Train Loss: 74337.34 (Recon: 68719.70, KLD: 112.35, Beta: 50.00) | Val Loss: 73985.66 (Recon: 68298.29, KLD: 113.75)
#   ** New best validation loss: 73985.6641. Saving model state. **
# Epoch 1932/4000 [0.61s] - Train Loss: 74288.53 (Recon: 68620.11, KLD: 113.37, Beta: 50.00) | Val Loss: 74082.97 (Recon: 68475.66, KLD: 112.15)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1933/4000 [0.63s] - Train Loss: 74475.51 (Recon: 68834.64, KLD: 112.82, Beta: 50.00) | Val Loss: 74144.80 (Recon: 68459.65, KLD: 113.70)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1934/4000 [0.65s] - Train Loss: 74365.83 (Recon: 68707.01, KLD: 113.18, Beta: 50.00) | Val Loss: 73843.05 (Recon: 68309.29, KLD: 110.68)
#   ** New best validation loss: 73843.0547. Saving model state. **
# Epoch 1935/4000 [0.61s] - Train Loss: 74521.26 (Recon: 68980.07, KLD: 110.82, Beta: 50.00) | Val Loss: 74161.08 (Recon: 68521.48, KLD: 112.79)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1936/4000 [0.61s] - Train Loss: 74509.89 (Recon: 68831.38, KLD: 113.57, Beta: 50.00) | Val Loss: 74123.77 (Recon: 68431.47, KLD: 113.85)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1937/4000 [0.62s] - Train Loss: 74271.15 (Recon: 68625.63, KLD: 112.91, Beta: 50.00) | Val Loss: 74275.24 (Recon: 68653.36, KLD: 112.44)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1938/4000 [0.61s] - Train Loss: 74214.36 (Recon: 68551.25, KLD: 113.26, Beta: 50.00) | Val Loss: 74160.72 (Recon: 68486.88, KLD: 113.48)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1939/4000 [0.61s] - Train Loss: 74432.02 (Recon: 68763.23, KLD: 113.38, Beta: 50.00) | Val Loss: 74158.33 (Recon: 68549.22, KLD: 112.18)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1940/4000 [0.61s] - Train Loss: 74480.11 (Recon: 68808.48, KLD: 113.43, Beta: 50.00) | Val Loss: 74122.55 (Recon: 68448.55, KLD: 113.48)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1941/4000 [0.64s] - Train Loss: 74377.38 (Recon: 68749.33, KLD: 112.56, Beta: 50.00) | Val Loss: 74259.29 (Recon: 68700.61, KLD: 111.17)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1942/4000 [0.75s] - Train Loss: 74413.66 (Recon: 68807.39, KLD: 112.13, Beta: 50.00) | Val Loss: 74188.39 (Recon: 68538.54, KLD: 113.00)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1943/4000 [0.70s] - Train Loss: 74392.33 (Recon: 68808.98, KLD: 111.67, Beta: 50.00) | Val Loss: 74149.52 (Recon: 68573.77, KLD: 111.51)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1944/4000 [0.72s] - Train Loss: 74415.41 (Recon: 68732.71, KLD: 113.65, Beta: 50.00) | Val Loss: 73940.31 (Recon: 68310.07, KLD: 112.60)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1945/4000 [0.71s] - Train Loss: 74449.77 (Recon: 68881.23, KLD: 111.37, Beta: 50.00) | Val Loss: 74234.39 (Recon: 68684.61, KLD: 111.00)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1946/4000 [0.61s] - Train Loss: 74251.83 (Recon: 68632.35, KLD: 112.39, Beta: 50.00) | Val Loss: 73748.02 (Recon: 68127.71, KLD: 112.41)
#   ** New best validation loss: 73748.0234. Saving model state. **
# Epoch 1947/4000 [0.61s] - Train Loss: 74524.97 (Recon: 68920.31, KLD: 112.09, Beta: 50.00) | Val Loss: 74098.31 (Recon: 68477.38, KLD: 112.42)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1948/4000 [0.61s] - Train Loss: 74437.85 (Recon: 68778.95, KLD: 113.18, Beta: 50.00) | Val Loss: 74247.33 (Recon: 68545.86, KLD: 114.03)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1949/4000 [0.61s] - Train Loss: 74341.74 (Recon: 68736.60, KLD: 112.10, Beta: 50.00) | Val Loss: 74040.07 (Recon: 68424.06, KLD: 112.32)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1950/4000 [0.61s] - Train Loss: 74279.31 (Recon: 68630.40, KLD: 112.98, Beta: 50.00) | Val Loss: 74109.66 (Recon: 68381.93, KLD: 114.55)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1951/4000 [0.62s] - Train Loss: 74248.49 (Recon: 68502.84, KLD: 114.91, Beta: 50.00) | Val Loss: 74040.25 (Recon: 68383.88, KLD: 113.13)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1952/4000 [0.61s] - Train Loss: 74214.65 (Recon: 68564.01, KLD: 113.01, Beta: 50.00) | Val Loss: 74013.77 (Recon: 68368.91, KLD: 112.90)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1953/4000 [0.62s] - Train Loss: 74369.58 (Recon: 68680.22, KLD: 113.79, Beta: 50.00) | Val Loss: 73920.88 (Recon: 68292.27, KLD: 112.57)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1954/4000 [0.62s] - Train Loss: 74205.61 (Recon: 68606.95, KLD: 111.97, Beta: 50.00) | Val Loss: 73976.40 (Recon: 68400.74, KLD: 111.51)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1955/4000 [0.61s] - Train Loss: 74331.83 (Recon: 68706.08, KLD: 112.52, Beta: 50.00) | Val Loss: 74179.74 (Recon: 68468.14, KLD: 114.23)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1956/4000 [0.63s] - Train Loss: 74216.44 (Recon: 68511.03, KLD: 114.11, Beta: 50.00) | Val Loss: 74042.12 (Recon: 68372.01, KLD: 113.40)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1957/4000 [0.61s] - Train Loss: 74342.52 (Recon: 68692.48, KLD: 113.00, Beta: 50.00) | Val Loss: 73731.82 (Recon: 67934.21, KLD: 115.95)
#   ** New best validation loss: 73731.8203. Saving model state. **
# Epoch 1958/4000 [0.62s] - Train Loss: 74232.86 (Recon: 68430.10, KLD: 116.06, Beta: 50.00) | Val Loss: 73891.99 (Recon: 68285.20, KLD: 112.14)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1959/4000 [0.61s] - Train Loss: 74402.50 (Recon: 68813.67, KLD: 111.78, Beta: 50.00) | Val Loss: 74117.14 (Recon: 68352.27, KLD: 115.30)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1960/4000 [0.64s] - Train Loss: 74253.26 (Recon: 68476.47, KLD: 115.54, Beta: 50.00) | Val Loss: 74103.36 (Recon: 68493.66, KLD: 112.19)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1961/4000 [0.72s] - Train Loss: 74220.57 (Recon: 68631.72, KLD: 111.78, Beta: 50.00) | Val Loss: 74289.73 (Recon: 68639.98, KLD: 113.00)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1962/4000 [0.73s] - Train Loss: 74552.28 (Recon: 68801.12, KLD: 115.02, Beta: 50.00) | Val Loss: 74251.91 (Recon: 68542.12, KLD: 114.20)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1963/4000 [0.73s] - Train Loss: 74256.53 (Recon: 68638.37, KLD: 112.36, Beta: 50.00) | Val Loss: 73877.44 (Recon: 68279.05, KLD: 111.97)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1964/4000 [0.71s] - Train Loss: 74243.20 (Recon: 68631.32, KLD: 112.24, Beta: 50.00) | Val Loss: 73811.62 (Recon: 68086.23, KLD: 114.51)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1965/4000 [0.63s] - Train Loss: 74205.11 (Recon: 68506.25, KLD: 113.98, Beta: 50.00) | Val Loss: 74148.84 (Recon: 68469.31, KLD: 113.59)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1966/4000 [0.61s] - Train Loss: 74157.89 (Recon: 68468.38, KLD: 113.79, Beta: 50.00) | Val Loss: 74119.67 (Recon: 68338.41, KLD: 115.63)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1967/4000 [0.61s] - Train Loss: 74304.46 (Recon: 68498.80, KLD: 116.11, Beta: 50.00) | Val Loss: 73885.80 (Recon: 68190.83, KLD: 113.90)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1968/4000 [0.61s] - Train Loss: 74236.67 (Recon: 68597.71, KLD: 112.78, Beta: 50.00) | Val Loss: 74060.40 (Recon: 68462.55, KLD: 111.96)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1969/4000 [0.61s] - Train Loss: 74267.62 (Recon: 68637.87, KLD: 112.60, Beta: 50.00) | Val Loss: 73851.28 (Recon: 68171.86, KLD: 113.59)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1970/4000 [0.62s] - Train Loss: 74143.48 (Recon: 68480.85, KLD: 113.25, Beta: 50.00) | Val Loss: 73991.55 (Recon: 68469.46, KLD: 110.44)
#   Validation loss did not improve for 13 epoch(s).
# Epoch 1971/4000 [0.62s] - Train Loss: 74275.40 (Recon: 68758.05, KLD: 110.35, Beta: 50.00) | Val Loss: 74056.05 (Recon: 68400.27, KLD: 113.12)
#   Validation loss did not improve for 14 epoch(s).
# Epoch 1972/4000 [0.61s] - Train Loss: 74393.04 (Recon: 68663.23, KLD: 114.60, Beta: 50.00) | Val Loss: 73930.83 (Recon: 68374.01, KLD: 111.14)
#   Validation loss did not improve for 15 epoch(s).
# Epoch 1973/4000 [0.63s] - Train Loss: 74207.64 (Recon: 68654.72, KLD: 111.06, Beta: 50.00) | Val Loss: 73848.92 (Recon: 68115.54, KLD: 114.67)
#   Validation loss did not improve for 16 epoch(s).
# Epoch 1974/4000 [0.61s] - Train Loss: 74295.65 (Recon: 68466.87, KLD: 116.58, Beta: 50.00) | Val Loss: 74209.33 (Recon: 68533.34, KLD: 113.52)
#   Validation loss did not improve for 17 epoch(s).
# Epoch 1975/4000 [0.62s] - Train Loss: 74310.39 (Recon: 68675.57, KLD: 112.70, Beta: 50.00) | Val Loss: 74110.13 (Recon: 68462.78, KLD: 112.95)
#   Validation loss did not improve for 18 epoch(s).
# Epoch 1976/4000 [0.61s] - Train Loss: 74098.17 (Recon: 68371.90, KLD: 114.53, Beta: 50.00) | Val Loss: 74001.36 (Recon: 68357.36, KLD: 112.88)
#   Validation loss did not improve for 19 epoch(s).
# Epoch 1977/4000 [0.61s] - Train Loss: 74122.80 (Recon: 68507.79, KLD: 112.30, Beta: 50.00) | Val Loss: 73879.47 (Recon: 68222.30, KLD: 113.14)
#   Validation loss did not improve for 20 epoch(s).
# Epoch 1978/4000 [0.61s] - Train Loss: 74328.33 (Recon: 68578.19, KLD: 115.00, Beta: 50.00) | Val Loss: 73855.34 (Recon: 68172.07, KLD: 113.67)
#   Validation loss did not improve for 21 epoch(s).
# Epoch 1979/4000 [0.61s] - Train Loss: 74186.40 (Recon: 68604.07, KLD: 111.65, Beta: 50.00) | Val Loss: 73832.47 (Recon: 68238.73, KLD: 111.87)
#   Validation loss did not improve for 22 epoch(s).
# Epoch 1980/4000 [0.62s] - Train Loss: 74103.86 (Recon: 68438.88, KLD: 113.30, Beta: 50.00) | Val Loss: 74071.76 (Recon: 68351.47, KLD: 114.41)
#   Validation loss did not improve for 23 epoch(s).
# Epoch 1981/4000 [0.64s] - Train Loss: 74180.47 (Recon: 68518.10, KLD: 113.25, Beta: 50.00) | Val Loss: 73594.93 (Recon: 67979.03, KLD: 112.32)
#   ** New best validation loss: 73594.9297. Saving model state. **
# Epoch 1982/4000 [0.71s] - Train Loss: 74125.24 (Recon: 68455.47, KLD: 113.40, Beta: 50.00) | Val Loss: 73961.95 (Recon: 68211.98, KLD: 115.00)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 1983/4000 [0.73s] - Train Loss: 74228.73 (Recon: 68456.29, KLD: 115.45, Beta: 50.00) | Val Loss: 73757.77 (Recon: 68136.62, KLD: 112.42)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 1984/4000 [0.75s] - Train Loss: 74320.66 (Recon: 68674.59, KLD: 112.92, Beta: 50.00) | Val Loss: 73951.99 (Recon: 68243.88, KLD: 114.16)
#   Validation loss did not improve for 3 epoch(s).
# Epoch 1985/4000 [0.61s] - Train Loss: 74200.32 (Recon: 68483.11, KLD: 114.34, Beta: 50.00) | Val Loss: 73684.70 (Recon: 68042.90, KLD: 112.84)
#   Validation loss did not improve for 4 epoch(s).
# Epoch 1986/4000 [0.61s] - Train Loss: 74168.28 (Recon: 68508.30, KLD: 113.20, Beta: 50.00) | Val Loss: 73822.59 (Recon: 68114.17, KLD: 114.17)
#   Validation loss did not improve for 5 epoch(s).
# Epoch 1987/4000 [0.61s] - Train Loss: 74269.96 (Recon: 68560.76, KLD: 114.18, Beta: 50.00) | Val Loss: 73808.90 (Recon: 68137.07, KLD: 113.44)
#   Validation loss did not improve for 6 epoch(s).
# Epoch 1988/4000 [0.61s] - Train Loss: 74323.28 (Recon: 68582.70, KLD: 114.81, Beta: 50.00) | Val Loss: 73884.73 (Recon: 68085.46, KLD: 115.99)
#   Validation loss did not improve for 7 epoch(s).
# Epoch 1989/4000 [0.61s] - Train Loss: 74250.45 (Recon: 68444.39, KLD: 116.12, Beta: 50.00) | Val Loss: 73655.16 (Recon: 67934.15, KLD: 114.42)
#   Validation loss did not improve for 8 epoch(s).
# Epoch 1990/4000 [0.61s] - Train Loss: 74053.04 (Recon: 68338.08, KLD: 114.30, Beta: 50.00) | Val Loss: 74041.00 (Recon: 68378.07, KLD: 113.26)
#   Validation loss did not improve for 9 epoch(s).
# Epoch 1991/4000 [0.61s] - Train Loss: 74284.02 (Recon: 68469.50, KLD: 116.29, Beta: 50.00) | Val Loss: 73736.70 (Recon: 67952.02, KLD: 115.69)
#   Validation loss did not improve for 10 epoch(s).
# Epoch 1992/4000 [0.61s] - Train Loss: 74006.21 (Recon: 68308.96, KLD: 113.95, Beta: 50.00) | Val Loss: 73849.60 (Recon: 68154.46, KLD: 113.90)
#   Validation loss did not improve for 11 epoch(s).
# Epoch 1993/4000 [0.62s] - Train Loss: 73895.74 (Recon: 68185.08, KLD: 114.21, Beta: 50.00) | Val Loss: 74138.84 (Recon: 68409.49, KLD: 114.59)
#   Validation loss did not improve for 12 epoch(s).
# Epoch 1994/4000 [0.62s] - Train Loss: 74185.51 (Recon: 68550.31, KLD: 112.70, Beta: 50.00) | Val Loss: 73960.70 (Recon: 68399.88, KLD: 111.22)
#   Validation loss did not improve for 13 epoch(s).
# Epoch 1995/4000 [0.61s] - Train Loss: 74083.90 (Recon: 68484.50, KLD: 111.99, Beta: 50.00) | Val Loss: 73680.62 (Recon: 67960.08, KLD: 114.41)
#   Validation loss did not improve for 14 epoch(s).
# Epoch 1996/4000 [0.61s] - Train Loss: 74021.51 (Recon: 68311.67, KLD: 114.20, Beta: 50.00) | Val Loss: 73934.27 (Recon: 68282.42, KLD: 113.04)
#   Validation loss did not improve for 15 epoch(s).
# Epoch 1997/4000 [0.61s] - Train Loss: 74019.47 (Recon: 68353.79, KLD: 113.31, Beta: 50.00) | Val Loss: 73949.42 (Recon: 68201.30, KLD: 114.96)
#   Validation loss did not improve for 16 epoch(s).
# Epoch 1998/4000 [0.62s] - Train Loss: 74112.68 (Recon: 68407.43, KLD: 114.10, Beta: 50.00) | Val Loss: 73887.35 (Recon: 68171.39, KLD: 114.32)
#   Validation loss did not improve for 17 epoch(s).
# Epoch 1999/4000 [0.62s] - Train Loss: 74073.14 (Recon: 68357.74, KLD: 114.31, Beta: 50.00) | Val Loss: 73886.92 (Recon: 68025.12, KLD: 117.24)
#   Validation loss did not improve for 18 epoch(s).
# Epoch 2000/4000 [0.61s] - Train Loss: 73916.53 (Recon: 68103.88, KLD: 116.25, Beta: 50.00) | Val Loss: 73636.95 (Recon: 67907.55, KLD: 114.59)
#   Validation loss did not improve for 19 epoch(s).
# Epoch 2001/4000 [0.67s] - Train Loss: 74139.46 (Recon: 68414.53, KLD: 114.50, Beta: 50.00) | Val Loss: 73974.87 (Recon: 68173.85, KLD: 116.02)
#   Validation loss did not improve for 20 epoch(s).
# Epoch 2002/4000 [0.72s] - Train Loss: 73875.44 (Recon: 68093.28, KLD: 115.64, Beta: 50.00) | Val Loss: 73800.71 (Recon: 68039.60, KLD: 115.22)
#   Validation loss did not improve for 21 epoch(s).
# Epoch 2003/4000 [0.73s] - Train Loss: 74062.91 (Recon: 68420.43, KLD: 112.85, Beta: 50.00) | Val Loss: 73974.04 (Recon: 68306.73, KLD: 113.35)
#   Validation loss did not improve for 22 epoch(s).
# Epoch 2004/4000 [0.71s] - Train Loss: 73989.63 (Recon: 68255.80, KLD: 114.68, Beta: 50.00) | Val Loss: 73794.69 (Recon: 68031.95, KLD: 115.25)
#   Validation loss did not improve for 23 epoch(s).
# Epoch 2005/4000 [0.69s] - Train Loss: 74009.02 (Recon: 68353.96, KLD: 113.10, Beta: 50.00) | Val Loss: 73723.35 (Recon: 68106.74, KLD: 112.33)
#   Validation loss did not improve for 24 epoch(s).
# Epoch 2006/4000 [0.62s] - Train Loss: 74004.79 (Recon: 68351.84, KLD: 113.06, Beta: 50.00) | Val Loss: 73702.28 (Recon: 67923.44, KLD: 115.58)
#   Validation loss did not improve for 25 epoch(s).
# Epoch 2007/4000 [0.63s] - Train Loss: 74022.73 (Recon: 68262.78, KLD: 115.20, Beta: 50.00) | Val Loss: 73482.11 (Recon: 67764.88, KLD: 114.34)
#   ** New best validation loss: 73482.1094. Saving model state. **
# Epoch 2008/4000 [0.62s] - Train Loss: 73961.18 (Recon: 68243.54, KLD: 114.35, Beta: 50.00) | Val Loss: 73949.38 (Recon: 68141.82, KLD: 116.15)
#   Validation loss did not improve for 1 epoch(s).
# Epoch 2009/4000 [0.61s] - Train Loss: 73762.63 (Recon: 67983.73, KLD: 115.58, Beta: 50.00) | Val Loss: 73767.30 (Recon: 68063.97, KLD: 114.07)
#   Validation loss did not improve for 2 epoch(s).
# Epoch 2010/4000 [0.61s] - Train Loss: 73989.85 (Recon: 68308.71, KLD: 113.62, Beta: 50.00) | Val Loss: 73879.57 (Recon: 68134.74, KLD: 114.90)
#   Validation loss did not improve for 3 epoch(s).
# ...
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training finished in 2.59 seconds.
# Evaluating LightGBM...
# Results for LightGBM_mu_sigma:
#   Accuracy: 0.7931
#   AUC:      0.6664
# Saved trained LightGBM_mu_sigma classifier to /content/drive/MyDrive/GrandMeanNorm/final_model_fold_1/LightGBM_mu_sigma.joblib
#
# --- Classifier Evaluation Summary ---
#
# Feature Type: Mu only
#   Logistic Regression: Accuracy=0.7701, AUC=0.7307
#   SVM (RBF Kernel): Accuracy=0.6552, AUC=0.3390
#   SVM (Linear Kernel): Accuracy=0.7816, AUC=0.2686
#   Random Forest: Accuracy=0.7816, AUC=0.6029
#   LightGBM: Accuracy=0.7586, AUC=0.6912
#
# Feature Type: Mu + Sigma
#   Logistic Regression: Accuracy=0.7586, AUC=0.7268
#   SVM (RBF Kernel): Accuracy=0.6207, AUC=0.3135
#   SVM (Linear Kernel): Accuracy=0.7816, AUC=0.2701
#   Random Forest: Accuracy=0.7816, AUC=0.6718
#   LightGBM: Accuracy=0.7931, AUC=0.6664
#
# --- Final Run Finished ---
